# %% [markdown]
# # 📚**About Dataset**
# The dataset obtained from scraping the website "rumah.com" contains information on property listings. The data includes the property's link, location, price, number of bedrooms, number of bathrooms, and floor area. With this dataset, one can analyze property prices and characteristics to gain insights into the real estate market represented on the website.
#
# Rumah.com is an online platform for buying and selling properties.
#
# **Columns**
# *   nav-hlink-ref: url
# *   listing-location: location of the property
# * price: price of the property
# * bed: number of bedroom in the property
# * bath: number of bathroom in the property
# * listing-floorarea: floor area in m2
# * listing-floorarea 2: property's price per m2
#
#
# 🔗 https://www.kaggle.com/datasets/gerryzani/housing-price-in-south-tangerang-city-indonesia/data

# %% [markdown]
# # 🚗 Import Libraries and Data

# %%
import pandas as pd
import numpy as np

# %%
housing_df = pd.read_csv("/content/tangsel_housing.csv", encoding='latin1')

# %% [markdown]
# # 🏗 **STRUCTURING**

# %% [markdown]
# ## Melihat Tipe Data

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29420 entries, 0 to 29419
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nav-link href        29420 non-null  object
#  1   listing-location     29420 non-null  object
#  2   price                29420 non-null  object
#  3   bed                  29282 non-null  float64
#  4   bath                 29215 non-null  float64
#  5   listing-floorarea    29420 non-null  object
#  6   listing-floorarea 2  29383 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.6+ MB

# %%
housing_df.describe()
# Out:
#                 bed          bath
# count  29282.000000  29215.000000
# mean       3.754457      2.986137
# std        1.356762      1.359788
# min        1.000000      1.000000
# 25%        3.000000      2.000000
# 50%        4.000000      3.000000
# 75%        4.000000      4.000000
# max       10.000000     10.000000

# %%
housing_df
# Out:
#                                            nav-link href  \
# 0      https://www.rumah.com/listing-properti/dijual-...
# 1      https://www.rumah.com/listing-properti/dijual-...
# 2      https://www.rumah.com/listing-properti/dijual-...
# 3      https://www.rumah.com/listing-properti/dijual-...
# 4      https://www.rumah.com/listing-properti/dijual-...
# ...                                                  ...
# 29415  https://www.rumah.com/listing-properti/dijual-...
# 29416  https://www.rumah.com/listing-properti/dijual-...
# 29417  https://www.rumah.com/listing-properti/dijual-...
# 29418  https://www.rumah.com/listing-properti/dijual-...
# 29419  https://www.rumah.com/listing-properti/dijual-...
#
#                                 listing-location   price  bed  bath  \
# 0      Gading Serpong, Tangerang Selatan, Banten   6,9 M  5.0   5.0
# 1      Gading Serpong, Tangerang Selatan, Banten   4,5 M  3.0   3.0
# 2      Gading Serpong, Tangerang Selatan, Banten  3,95 M  3.0   3.0
# 3      Gading Serpong, Tangerang Selatan, Banten   3,3 M  4.0   3.0
# 4      Gading Serpong, Tangerang Selatan, Banten   3,5 M  3.0   2.0
# ...                                          ...     ...  ...   ...
# 29415         Bintaro, Tangerang Selatan, Banten   3,3 M  3.0   3.0
# 29416         Bintaro, Tangerang Selatan, Banten     4 M  8.0   4.0
# 29417         Bintaro, Tangerang Selatan, Banten   2,2 M  3.0   2.0
# 29418         Bintaro, Tangerang Selatan, Banten  1,95 M  3.0   2.0
# 29419         Bintaro, Tangerang Selatan, Banten   5,5 M  4.0   3.0
#
#       listing-floorarea   listing-floorarea 2
# 0                420 m²  Rp 20.720.721 per m²
# 1                190 m²  Rp 12.747.875 per m²
# 2                132 m²  Rp 30.859.375 per m²
# 3                220 m²  Rp 18.333.333 per m²
# 4                180 m²  Rp 27.777.778 per m²
# ...                 ...                   ...
# 29415            300 m²  Rp 21.710.526 per m²
# 29416            330 m²  Rp 36.363.636 per m²
# 29417            160 m²  Rp 18.333.333 per m²
# 29418            120 m²  Rp 21.666.667 per m²
# 29419            200 m²  Rp 30.555.556 per m²
#
# [29420 rows x 7 columns]

# %% [markdown]
# nanti di bagian enriching

# %% [markdown]
# ##Convert Floor Area

# %%
housing_df['floor_area'] = housing_df['listing-floorarea'].str.replace('m²','')

# %%
housing_df['floor_area'] = housing_df['floor_area'].astype(float)

# %% [markdown]
# ## Convert Price Per m2

# %%
housing_df['price_per_m2'] = housing_df['listing-floorarea 2'].str.replace('Rp', '')
housing_df['price_per_m2'] = housing_df['price_per_m2'].str.replace('.', '')
housing_df['price_per_m2'] = housing_df['price_per_m2'].str[:-7]
housing_df['price_per_m2'] = housing_df['price_per_m2'].str.lstrip()

# %%
housing_df['price_per_m2'] = housing_df['price_per_m2'].astype(float)

# %% [markdown]
# ## Convert Price into numeric

# %%
housing_df['price'].str.contains('Rp').sum()
# Out:
# np.int64(4)

# %%
housing_df.loc[housing_df['price'].str.contains('Rp')]
# Out:
#                                          nav-link href  \
# 613  https://www.rumah.com/listing-properti/proyek/...
# 622  https://www.rumah.com/listing-properti/proyek/...
# 623  https://www.rumah.com/listing-properti/proyek/...
# 624  https://www.rumah.com/listing-properti/proyek/...
#
#                                       listing-location                price  \
# 613  10 Jl. Ki Hajar Dewantara, Ciputat, Tangerang ...     2,2 M - Rp 2,7 M
# 622  Jl.Inpres, RT 02/ RW 09, Pamulang, Tangerang S...  875,5 jt - Rp 1,1 M
# 623      Jl Benosa, Serpong, Tangerang Selatan, Banten    1,08 M - Rp 2,3 M
# 624  99 Jalan raya pengasinan, BSD, Tangerang Selat...      800 jt - Rp 1 M
#
#      bed  bath listing-floorarea listing-floorarea 2  floor_area  price_per_m2
# 613  4.0   3.0            140 m²                 NaN       140.0           NaN
# 622  2.0   2.0             52 m²                 NaN        52.0           NaN
# 623  2.0   2.0             69 m²                 NaN        69.0           NaN
# 624  3.0   2.0             63 m²                 NaN        63.0           NaN

# %%
housing_df.loc[613, 'price'] = '2,45 M'
housing_df.loc[622, 'price'] = '987,75 jt'
housing_df.loc[623, 'price'] = '1,69 M'
housing_df.loc[624, 'price'] = '900 jt'

# %%
housing_df.loc[housing_df['price'].str.contains('rb')]
# Out:
#                                            nav-link href  \
# 6175   https://www.rumah.com/listing-properti/dijual-...
# 8497   https://www.rumah.com/listing-properti/dijual-...
# 8622   https://www.rumah.com/listing-properti/dijual-...
# 11760  https://www.rumah.com/listing-properti/dijual-...
# 12720  https://www.rumah.com/listing-properti/dijual-...
# 13288  https://www.rumah.com/listing-properti/dijual-...
# 13557  https://www.rumah.com/listing-properti/dijual-...
# 14477  https://www.rumah.com/listing-properti/dijual-...
# 16585  https://www.rumah.com/listing-properti/dijual-...
# 17032  https://www.rumah.com/listing-properti/dijual-...
# 18012  https://www.rumah.com/listing-properti/dijual-...
# 20858  https://www.rumah.com/listing-properti/dijual-...
# 23302  https://www.rumah.com/listing-properti/dijual-...
# 25935  https://www.rumah.com/listing-properti/dijual-...
#
#                                         listing-location     price  bed  bath  \
# 6175                 Pamulang, Tangerang Selatan, Banten    875 rb  3.0   2.0
# 8497                  Serpong, Tangerang Selatan, Banten    300 rb  3.0   1.0
# 8622                  Serpong, Tangerang Selatan, Banten    600 rb  3.0   1.0
# 11760                Pamulang, Tangerang Selatan, Banten      1 rb  2.0   1.0
# 12720                Pamulang, Tangerang Selatan, Banten      1 rb  2.0   1.0
# 13288  Jl beruang 2 bintaro, Bintaro, Tangerang Selat...    675 rb  2.0   2.0
# 13557  Pondok benda pamulang, Pamulang, Tangerang Sel...    800 rb  3.0   2.0
# 14477  Jln raya sengkol, Pamulang, Tangerang Selatan,...    750 rb  2.0   1.0
# 16585                 Serpong, Tangerang Selatan, Banten    900 rb  3.0   1.0
# 17032  Pamulang Raya, Pamulang, Tangerang Selatan, Ba...    900 rb  3.0   2.0
# 18012  Pamulang Raya, Pamulang, Tangerang Selatan, Ba...    900 rb  3.0   2.0
# 20858        serpong, Serpong, Tangerang Selatan, Banten    830 rb  3.0   2.0
# 23302                     BSD, Tangerang Selatan, Banten    999 rb  2.0   2.0
# 25935  Graha Bintaro, Bintaro, Tangerang Selatan, Banten  1,999 rb  3.0   3.0
#
#       listing-floorarea listing-floorarea 2  floor_area  price_per_m2
# 6175              70 m²    Rp 14.583 per m²        70.0       14583.0
# 8497              46 m²     Rp 5.000 per m²        46.0        5000.0
# 8622              66 m²    Rp 10.000 per m²        66.0       10000.0
# 11760             10 m²       Rp 100 per m²        10.0         100.0
# 12720             10 m²       Rp 100 per m²        10.0         100.0
# 13288             50 m²    Rp 15.000 per m²        50.0       15000.0
# 13557             88 m²    Rp 11.429 per m²        88.0       11429.0
# 14477             50 m²     Rp 9.868 per m²        50.0        9868.0
# 16585             60 m²    Rp 10.000 per m²        60.0       10000.0
# 17032             54 m²     Rp 7.500 per m²        54.0        7500.0
# 18012             54 m²     Rp 7.500 per m²        54.0        7500.0
# 20858             60 m²    Rp 13.833 per m²        60.0       13833.0
# 23302             84 m²    Rp 16.932 per m²        84.0       16932.0
# 25935            120 m²        Rp 20 per m²       120.0          20.0

# %%
housing_df['price_num'] = housing_df['price'].str.lower()
housing_df['price_num'] = housing_df['price_num'].str.replace('rp', '')
housing_df['price_num'] = housing_df['price_num'].str.replace(',', '.')

# %%
housing_df['price_num']
# Out:
# 0         6.9 m
# 1         4.5 m
# 2        3.95 m
# 3         3.3 m
# 4         3.5 m
#           ...
# 29415     3.3 m
# 29416       4 m
# 29417     2.2 m
# 29418    1.95 m
# 29419     5.5 m
# Name: price_num, Length: 29420, dtype: object

# %%
for i in range(len(housing_df)):
  if 'm' in housing_df.loc[i,'price_num']:
    housing_df.loc[i, 'price_num'] = housing_df.loc[i,'price_num'].replace('m', '')
    housing_df.loc[i, 'price_num'] = float(housing_df.loc[i,'price_num']) * 1000000000
  elif 'jt' in housing_df.loc[i,'price_num']:
    housing_df.loc[i, 'price_num'] = housing_df.loc[i,'price_num'].replace('jt', '')
    housing_df.loc[i, 'price_num'] = float(housing_df.loc[i,'price_num']) * 1000000
  elif 'rb' in housing_df.loc[i,'price_num']:
    housing_df.loc[i, 'price_num'] = housing_df.loc[i,'price_num'].replace('rb', '')
    housing_df.loc[i, 'price_num'] = float(housing_df.loc[i,'price_num']) * 1000

# %%
housing_df['price_num'] = housing_df['price_num'].astype(float)

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29420 entries, 0 to 29419
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nav-link href        29420 non-null  object
#  1   listing-location     29420 non-null  object
#  2   price                29420 non-null  object
#  3   bed                  29282 non-null  float64
#  4   bath                 29215 non-null  float64
#  5   listing-floorarea    29420 non-null  object
#  6   listing-floorarea 2  29383 non-null  object
#  7   floor_area           29420 non-null  float64
#  8   price_per_m2         29383 non-null  float64
#  9   price_num            29420 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# # 🧹**CLEANING**

# %% [markdown]
# ## Handling Duplicate Data

# %%
housing_df.duplicated().sum()
# Out:
# np.int64(5241)

# %%
housing_df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Handling Missing Value

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24179 entries, 0 to 29419
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nav-link href        24179 non-null  object
#  1   listing-location     24179 non-null  object
#  2   price                24179 non-null  object
#  3   bed                  24069 non-null  float64
#  4   bath                 24016 non-null  float64
#  5   listing-floorarea    24179 non-null  object
#  6   listing-floorarea 2  24145 non-null  object
#  7   floor_area           24179 non-null  float64
#  8   price_per_m2         24145 non-null  float64
#  9   price_num            24179 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.0+ MB

# %%
housing_df.isna().sum()
# Out:
# nav-link href            0
# listing-location         0
# price                    0
# bed                    110
# bath                   163
# listing-floorarea        0
# listing-floorarea 2     34
# floor_area               0
# price_per_m2            34
# price_num                0
# dtype: int64

# %%
housing_df.loc[housing_df['bed'].isna()]
# Out:
#                                            nav-link href  \
# 52     https://www.rumah.com/listing-properti/dijual-...
# 285    https://www.rumah.com/listing-properti/dijual-...
# 328    https://www.rumah.com/listing-properti/dijual-...
# 633    https://www.rumah.com/listing-properti/dijual-...
# 923    https://www.rumah.com/listing-properti/dijual-...
# ...                                                  ...
# 27026  https://www.rumah.com/listing-properti/dijual-...
# 27029  https://www.rumah.com/listing-properti/dijual-...
# 27150  https://www.rumah.com/listing-properti/dijual-...
# 27233  https://www.rumah.com/listing-properti/dijual-...
# 27957  https://www.rumah.com/listing-properti/dijual-...
#
#                                         listing-location    price  bed  bath  \
# 52     Jl Jombang Raya Bintaro Ciputat, Ciputat, Tang...   1,43 M  NaN   NaN
# 285                   Bintaro, Tangerang Selatan, Banten      2 M  NaN   NaN
# 328    Plumeria GR 23, Pondok Aren, Tangerang Selatan...    1,2 M  NaN   NaN
# 633                       BSD, Tangerang Selatan, Banten   19,5 M  NaN   NaN
# 923    Jl. Discovery Aluvia, Pondok Aren, Tangerang S...  3,159 M  NaN   NaN
# ...                                                  ...      ...  ...   ...
# 27026  Perumahan bukit mas, Bintaro, Tangerang Selata...      6 M  NaN   NaN
# 27029                 Ciputat, Tangerang Selatan, Banten    1,8 M  NaN   NaN
# 27150                 Bintaro, Tangerang Selatan, Banten    6,5 M  NaN   NaN
# 27233                 Bintaro, Tangerang Selatan, Banten     45 M  NaN   NaN
# 27957  Jl. Raya Jombang, Pondok Aren, Tangerang Selat...    1,5 M  NaN   NaN
#
#       listing-floorarea   listing-floorarea 2  floor_area  price_per_m2  \
# 52                94 m²  Rp 20.140.845 per m²        94.0    20140845.0
# 285              162 m²  Rp 18.181.818 per m²       162.0    18181818.0
# 328               69 m²  Rp 20.000.000 per m²        69.0    20000000.0
# 633              151 m²  Rp 29.862.175 per m²       151.0    29862175.0
# 923              110 m²  Rp 35.100.000 per m²       110.0    35100000.0
# ...                 ...                   ...         ...           ...
# 27026            275 m²  Rp 12.000.000 per m²       275.0    12000000.0
# 27029            130 m²  Rp 12.676.056 per m²       130.0    12676056.0
# 27150            300 m²  Rp 18.258.427 per m²       300.0    18258427.0
# 27233           3000 m²  Rp 35.828.025 per m²      3000.0    35828025.0
# 27957             70 m²   Rp 9.375.000 per m²        70.0     9375000.0
#
#           price_num
# 52     1.430000e+09
# 285    2.000000e+09
# 328    1.200000e+09
# 633    1.950000e+10
# 923    3.159000e+09
# ...             ...
# 27026  6.000000e+09
# 27029  1.800000e+09
# 27150  6.500000e+09
# 27233  4.500000e+10
# 27957  1.500000e+09
#
# [110 rows x 10 columns]

# %%
housing_df['bed'] = housing_df['bed'].fillna(0)
housing_df['bath'] = housing_df['bath'].fillna(0)

# %%
housing_df.loc[housing_df['price_per_m2'].isna()]
# Out:
#                                            nav-link href  \
# 474    https://www.rumah.com/listing-properti/dijual-...
# 612    https://www.rumah.com/listing-properti/proyek/...
# 613    https://www.rumah.com/listing-properti/proyek/...
# 614    https://www.rumah.com/listing-properti/proyek/...
# 616    https://www.rumah.com/listing-properti/proyek/...
# 622    https://www.rumah.com/listing-properti/proyek/...
# 623    https://www.rumah.com/listing-properti/proyek/...
# 624    https://www.rumah.com/listing-properti/proyek/...
# 625    https://www.rumah.com/listing-properti/proyek/...
# 1224   https://www.rumah.com/listing-properti/dijual-...
# 4208   https://www.rumah.com/listing-properti/dijual-...
# 6153   https://www.rumah.com/listing-properti/dijual-...
# 6837   https://www.rumah.com/listing-properti/dijual-...
# 10221  https://www.rumah.com/listing-properti/dijual-...
# 10639  https://www.rumah.com/listing-properti/dijual-...
# 10647  https://www.rumah.com/listing-properti/dijual-...
# 10843  https://www.rumah.com/listing-properti/dijual-...
# 10965  https://www.rumah.com/listing-properti/dijual-...
# 13264  https://www.rumah.com/listing-properti/dijual-...
# 13277  https://www.rumah.com/listing-properti/dijual-...
# 14230  https://www.rumah.com/listing-properti/dijual-...
# 14245  https://www.rumah.com/listing-properti/dijual-...
# 14510  https://www.rumah.com/listing-properti/dijual-...
# 19784  https://www.rumah.com/listing-properti/dijual-...
# 19954  https://www.rumah.com/listing-properti/dijual-...
# 20507  https://www.rumah.com/listing-properti/dijual-...
# 20918  https://www.rumah.com/listing-properti/dijual-...
# 22308  https://www.rumah.com/listing-properti/dijual-...
# 22747  https://www.rumah.com/listing-properti/dijual-...
# 23378  https://www.rumah.com/listing-properti/dijual-...
# 23998  https://www.rumah.com/listing-properti/dijual-...
# 25500  https://www.rumah.com/listing-properti/dijual-...
# 28805  https://www.rumah.com/listing-properti/dijual-...
# 29344  https://www.rumah.com/listing-properti/dijual-...
#
#                                         listing-location          price  bed  \
# 474    jl lengkong wetan, Serpong, Tangerang Selatan,...          1,5 M  4.0
# 612    Jl. Pinang Raya RT. 002 RW. 022 Pamulang Timur...  842,751837 jt  2.0
# 613    10 Jl. Ki Hajar Dewantara, Ciputat, Tangerang ...         2,45 M  4.0
# 614    33 Pdk.cempaka Rt.03,Rw.10, Rempoa, Ciputat Ti...          1,9 M  3.0
# 616    12 Jl Raya SouthCity Utara, Lot 5, Pamulang, T...      1,58286 M  3.0
# 622    Jl.Inpres, RT 02/ RW 09, Pamulang, Tangerang S...      987,75 jt  2.0
# 623        Jl Benosa, Serpong, Tangerang Selatan, Banten         1,69 M  2.0
# 624    99 Jalan raya pengasinan, BSD, Tangerang Selat...         900 jt  3.0
# 625    26 Jl. Kunir, Pd. Cabe Udik, Pamulang, Tangera...       1,7362 M  4.0
# 1224       Jl. Amd V, Bintaro, Tangerang Selatan, Banten       959,8 jt  3.0
# 4208   Gading Serpong, Gading Serpong, Tangerang Sela...            2 M  4.0
# 6153           Gading Serpong, Tangerang Selatan, Banten          4,5 M  4.0
# 6837   Jalan Kemiri - Pondok cabe udik, Pamulang, Tan...          1,4 M  2.0
# 10221           Ciputat Timur, Tangerang Selatan, Banten         10,8 M  1.0
# 10639  Jl Cendrawasi Raya Bintaro, Bintaro, Tangerang...         1,29 M  3.0
# 10647  Jl Cendrawasih Raya, Ciputat Timur, Tangerang ...         1,29 M  3.0
# 10843  . Jl. KH. Dewantara Kp. Sawah Lama, Ciputat, T...          1,4 M  3.0
# 10965  Bintaro Sektor 9, Bintaro, Tangerang Selatan, ...          7,2 M  5.0
# 13264          Gading Serpong, Tangerang Selatan, Banten          1,5 M  0.0
# 13277          Gading Serpong, Tangerang Selatan, Banten          2,2 M  4.0
# 14230  Griya Bintaro Estate Jl. Raya Cendrawasih, Pam...         1,29 M  3.0
# 14245  Griya Bintaro Estate Jl. Raya Cendrawasih, Cip...         1,29 M  3.0
# 14510  BSD City Lengkong Kulon, Kec. Pagedangan, BSD,...           16 M  6.0
# 19784  Gading serpong, Gading Serpong, Tangerang Sela...         2,89 M  4.0
# 19954  GADING SERPONG - TANGERANG, Gading Serpong, Ta...    8,200009 jt  1.0
# 20507          Gading Serpong, Tangerang Selatan, Banten            8 M  4.0
# 20918                     BSD, Tangerang Selatan, Banten          3,6 M  4.0
# 22308             Pondok Aren, Tangerang Selatan, Banten         950 jt  2.0
# 22747  Gading serpong, Gading Serpong, Tangerang Sela...         2,86 M  4.0
# 23378  Jl. Permai Bar, Jurang Mangu Barat, Kec. Pd. A...            1 M  4.0
# 23998  Gading serpong, Gading Serpong, Tangerang Sela...         2,85 M  4.0
# 25500             Alam Sutera, Tangerang Selatan, Banten         1,75 M  2.0
# 28805          Gading Serpong, Tangerang Selatan, Banten         600 jt  2.0
# 29344       Jl. Puspitek, BSD, Tangerang Selatan, Banten          5,5 M  5.0
#
#        bath listing-floorarea listing-floorarea 2  floor_area  price_per_m2  \
# 474     3.0             72 m²                 NaN        72.0           NaN
# 612     1.0             36 m²                 NaN        36.0           NaN
# 613     3.0            140 m²                 NaN       140.0           NaN
# 614     2.0             84 m²                 NaN        84.0           NaN
# 616     3.0             71 m²                 NaN        71.0           NaN
# 622     2.0             52 m²                 NaN        52.0           NaN
# 623     2.0             69 m²                 NaN        69.0           NaN
# 624     2.0             63 m²                 NaN        63.0           NaN
# 625     4.0            126 m²                 NaN       126.0           NaN
# 1224    3.0             65 m²                 NaN        65.0           NaN
# 4208    3.0            180 m²                 NaN       180.0           NaN
# 6153    3.0            350 m²                 NaN       350.0           NaN
# 6837    1.0             36 m²                 NaN        36.0           NaN
# 10221   1.0           1000 m²                 NaN      1000.0           NaN
# 10639   2.0             68 m²                 NaN        68.0           NaN
# 10647   2.0             68 m²                 NaN        68.0           NaN
# 10843   3.0             90 m²                 NaN        90.0           NaN
# 10965   5.0            350 m²                 NaN       350.0           NaN
# 13264   0.0            100 m²                 NaN       100.0           NaN
# 13277   2.0             84 m²                 NaN        84.0           NaN
# 14230   2.0             68 m²                 NaN        68.0           NaN
# 14245   2.0             68 m²                 NaN        68.0           NaN
# 14510   6.0            375 m²                 NaN       375.0           NaN
# 19784   3.0            155 m²                 NaN       155.0           NaN
# 19954   0.0            297 m²                 NaN       297.0           NaN
# 20507   4.0            302 m²                 NaN       302.0           NaN
# 20918   4.0            180 m²                 NaN       180.0           NaN
# 22308   1.0           4570 m²                 NaN      4570.0           NaN
# 22747   3.0            155 m²                 NaN       155.0           NaN
# 23378   2.0            150 m²                 NaN       150.0           NaN
# 23998   3.0            155 m²                 NaN       155.0           NaN
# 25500   1.0             60 m²                 NaN        60.0           NaN
# 28805   1.0             60 m²                 NaN        60.0           NaN
# 29344   6.0            200 m²                 NaN       200.0           NaN
#
#           price_num
# 474    1.500000e+09
# 612    8.427518e+08
# 613    2.450000e+09
# 614    1.900000e+09
# 616    1.582860e+09
# 622    9.877500e+08
# 623    1.690000e+09
# 624    9.000000e+08
# 625    1.736200e+09
# 1224   9.598000e+08
# 4208   2.000000e+09
# 6153   4.500000e+09
# 6837   1.400000e+09
# 10221  1.080000e+10
# 10639  1.290000e+09
# 10647  1.290000e+09
# 10843  1.400000e+09
# 10965  7.200000e+09
# 13264  1.500000e+09
# 13277  2.200000e+09
# 14230  1.290000e+09
# 14245  1.290000e+09
# 14510  1.600000e+10
# 19784  2.890000e+09
# 19954  8.200009e+06
# 20507  8.000000e+09
# 20918  3.600000e+09
# 22308  9.500000e+08
# 22747  2.860000e+09
# 23378  1.000000e+09
# 23998  2.850000e+09
# 25500  1.750000e+09
# 28805  6.000000e+08
# 29344  5.500000e+09

# %%
housing_df['price_per_m2'] = housing_df['price_per_m2'].fillna(housing_df['price_num']/housing_df['floor_area'])
#diambil perkiraan harga per m2 dengan membagi harga jual dengan luas bangunan

# %% [markdown]
# ##Handling Outlier

# %%
housing_df.describe()
# Out:
#                 bed          bath     floor_area  price_per_m2     price_num
# count  24179.000000  24179.000000   24179.000000  2.417900e+04  2.417900e+04
# mean       3.740353      2.971256     211.664213  3.305532e+07  3.596452e+09
# std        1.374916      1.376736    2721.628300  5.283017e+08  7.259004e+09
# min        0.000000      0.000000       1.000000  0.000000e+00  1.000000e+00
# 25%        3.000000      2.000000      80.000000  1.325000e+07  1.350000e+09
# 50%        4.000000      3.000000     140.000000  1.840000e+07  2.500000e+09
# 75%        4.000000      4.000000     237.000000  2.428571e+07  4.350000e+09
# max       10.000000     10.000000  400000.000000  2.937500e+10  8.500000e+11

# %%
#mengecek tanah dengan harga per m2 di bawah 1 juta rupiah
housing_df.loc[housing_df['price_per_m2']<1000000]
# Out:
#                                            nav-link href  \
# 92     https://www.rumah.com/listing-properti/dijual-...
# 102    https://www.rumah.com/listing-properti/dijual-...
# 219    https://www.rumah.com/listing-properti/dijual-...
# 319    https://www.rumah.com/listing-properti/dijual-...
# 526    https://www.rumah.com/listing-properti/dijual-...
# ...                                                  ...
# 28893  https://www.rumah.com/listing-properti/dijual-...
# 29238  https://www.rumah.com/listing-properti/dijual-...
# 29326  https://www.rumah.com/listing-properti/dijual-...
# 29329  https://www.rumah.com/listing-properti/dijual-...
# 29368  https://www.rumah.com/listing-properti/dijual-...
#
#                                         listing-location     price  bed  bath  \
# 92        Graha raya, Bintaro, Tangerang Selatan, Banten    120 jt  4.0   2.0
# 102                  Pamulang, Tangerang Selatan, Banten       630  2.0   1.0
# 219    Malibu village gading serpong, Gading Serpong,...     45 jt  3.0   2.0
# 319    Jl. Hasyim Ashari, Cipondoh, Ciledug, Tangeran...     50 jt  2.0   2.0
# 526                       BSD, Tangerang Selatan, Banten     75 jt  3.0   3.0
# ...                                                  ...       ...  ...   ...
# 28893                Pamulang, Tangerang Selatan, Banten       800  3.0   2.0
# 29238             Pondok Aren, Tangerang Selatan, Banten     90 jt  6.0   4.0
# 29326  Townhouse puyuh barat, Bintaro, Tangerang Sela...  2,799 jt  4.0   2.0
# 29329  Jl. Puyuh barat IV, Bintaro, Tangerang Selatan...  2,799 jt  4.0   3.0
# 29368                 Bintaro, Tangerang Selatan, Banten    7,8 jt  5.0   2.0
#
#       listing-floorarea listing-floorarea 2  floor_area  price_per_m2  \
# 92               170 m²   Rp 666.667 per m²       170.0      666667.0
# 102               50 m²         Rp 7 per m²        50.0           7.0
# 219               55 m²   Rp 937.500 per m²        55.0      937500.0
# 319               50 m²   Rp 833.333 per m²        50.0      833333.0
# 526              144 m²   Rp 625.000 per m²       144.0      625000.0
# ...                 ...                 ...         ...           ...
# 28893             65 m²        Rp 13 per m²        65.0          13.0
# 29238            200 m²   Rp 545.455 per m²       200.0      545455.0
# 29326            275 m²    Rp 13.995 per m²       275.0       13995.0
# 29329            220 m²    Rp 17.828 per m²       220.0       17828.0
# 29368            412 m²    Rp 21.667 per m²       412.0       21667.0
#
#          price_num
# 92     120000000.0
# 102          630.0
# 219     45000000.0
# 319     50000000.0
# 526     75000000.0
# ...            ...
# 28893        800.0
# 29238   90000000.0
# 29326    2799000.0
# 29329    2799000.0
# 29368    7800000.0
#
# [236 rows x 10 columns]

# %%
#diputuskan menghapus baris dengan harga per m2 di bawah 1 juta rupiah
housing_df.drop(housing_df.loc[housing_df['price_per_m2']<1000000].index, inplace=True)

# %%
housing_df.loc[housing_df['price_per_m2']>5.0e+07]
# Out:
#                                            nav-link href  \
# 112    https://www.rumah.com/listing-properti/dijual-...
# 157    https://www.rumah.com/listing-properti/dijual-...
# 203    https://www.rumah.com/listing-properti/dijual-...
# 243    https://www.rumah.com/listing-properti/dijual-...
# 423    https://www.rumah.com/listing-properti/dijual-...
# ...                                                  ...
# 27820  https://www.rumah.com/listing-properti/dijual-...
# 27961  https://www.rumah.com/listing-properti/dijual-...
# 27994  https://www.rumah.com/listing-properti/dijual-...
# 29134  https://www.rumah.com/listing-properti/dijual-...
# 29270  https://www.rumah.com/listing-properti/dijual-...
#
#                                         listing-location     price  bed  bath  \
# 112    Gramercy Alam Sutera, Alam Sutera, Tangerang S...    21,1 M  6.0   7.0
# 157                   Bintaro, Tangerang Selatan, Banten      17 M  5.0   4.0
# 203    jl. BSD boulevard utara, BSD, Tangerang Selata...  21,749 M  5.0   5.0
# 243                   Bintaro, Tangerang Selatan, Banten      33 M  5.0   3.0
# 423                       BSD, Tangerang Selatan, Banten   1.450 M  3.0   2.0
# ...                                                  ...       ...  ...   ...
# 27820       Navapark BSD, BSD, Tangerang Selatan, Banten      15 M  4.0   3.0
# 27961           Lakewood, BSD, Tangerang Selatan, Banten      12 M  7.0   5.0
# 27994           Navapark, BSD, Tangerang Selatan, Banten      23 M  5.0   4.0
# 29134                     BSD, Tangerang Selatan, Banten     8,9 M  4.0   5.0
# 29270                     BSD, Tangerang Selatan, Banten      13 M  4.0   4.0
#
#       listing-floorarea       listing-floorarea 2  floor_area  price_per_m2  \
# 112              451 m²      Rp 50.238.095 per m²       451.0  5.023810e+07
# 157              502 m²      Rp 55.194.805 per m²       502.0  5.519480e+07
# 203              544 m²      Rp 57.997.333 per m²       544.0  5.799733e+07
# 243              198 m²     Rp 125.000.000 per m²       198.0  1.250000e+08
# 423               88 m²  Rp 25.892.857.143 per m²        88.0  2.589286e+10
# ...                 ...                       ...         ...           ...
# 27820            300 m²      Rp 75.000.000 per m²       300.0  7.500000e+07
# 27961            337 m²      Rp 54.545.455 per m²       337.0  5.454546e+07
# 27994            653 m²      Rp 61.333.333 per m²       653.0  6.133333e+07
# 29134            320 m²      Rp 69.531.250 per m²       320.0  6.953125e+07
# 29270            350 m²      Rp 56.521.739 per m²       350.0  5.652174e+07
#
#           price_num
# 112    2.110000e+10
# 157    1.700000e+10
# 203    2.174900e+10
# 243    3.300000e+10
# 423    1.450000e+09
# ...             ...
# 27820  1.500000e+10
# 27961  1.200000e+10
# 27994  2.300000e+10
# 29134  8.900000e+09
# 29270  1.300000e+10
#
# [224 rows x 10 columns]

# %% [markdown]
# # ✨**ENRICHING**

# %% [markdown]
# Menambahkan kecamatan lokasi bangunan tersebut dijual yang diperoleh dari kolom listing-location

# %%
housing_df['listing-location']
# Out:
# 0        Gading Serpong, Tangerang Selatan, Banten
# 1        Gading Serpong, Tangerang Selatan, Banten
# 2        Gading Serpong, Tangerang Selatan, Banten
# 3        Gading Serpong, Tangerang Selatan, Banten
# 4        Gading Serpong, Tangerang Selatan, Banten
#                            ...
# 29415           Bintaro, Tangerang Selatan, Banten
# 29416           Bintaro, Tangerang Selatan, Banten
# 29417           Bintaro, Tangerang Selatan, Banten
# 29418           Bintaro, Tangerang Selatan, Banten
# 29419           Bintaro, Tangerang Selatan, Banten
# Name: listing-location, Length: 23943, dtype: object

# %%
location_df = housing_df['listing-location'].str.lower()
location_df = location_df.str.replace(', banten','')
location_df = location_df.str.replace(', tangerang selatan','')
location_df = pd.DataFrame(location_df)

# %%
list(location_df.unique())
# Out:
# ['gading serpong',
#  'bsd',
#  'jalan cempaka, bintaro',
#  'alam sutera',
#  'jl gading serpong, gading serpong',
#  'bintaro',
#  'jl gading sektor, gading serpong',
#  'jl sektor gading serpong, gading serpong',
#  'serpong',
#  'jl cluster berryl, gading serpong',
#  'graha carissa, serpong utara',
#  'cluster graha raya bintaro, bintaro',
#  'sektor 9, bintaro',
#  'bintaro, bintaro',
#  'graha bintaro, bintaro',
#  'cluster strozzi symphonia gading serpong, bsd',
#  'jln pandawa, pamulang',
#  'pondok benda, pamulang',
#  'serpong paradise city, serpong',
#  'jl jombang raya bintaro ciputat, ciputat',
#  'lele 5, pamulang',
#  'bsd, bsd',
#  'alegria park, bsd city, bsd',
#  'jalan pondok aren, pondok aren',
#  'foresta bsd, bsd',
#  'ciputat timur',
#  'ciputat',
#  'jl. semeru 1 a2 no. 17, jombang, ciputat, ciputat',
#  'graha raya, serpong utara',
#  'serpong, serpong',
#  'jl wortel no 7 sektor 1.6 griya loka, serpong',
#  'gading serpong, pondok aren',
#  'gading serpong, pamulang',
#  'sektor 6, gading serpong',
#  'volta, gading serpong',
#  'taman berryl residence, serpong utara',
#  'jl. tarumanegara, ciputat timur',
#  'gading serpong, gading serpong',
#  'de latinos serpong bsd, bsd',
#  'greenwich bsd city, bsd',
#  'melati mas serpong, bsd',
#  'jl. teratai, pondok aren',
#  'jalan grisea raya no 1, gading serpong',
#  'bsd city, serpong utara',
#  'serpong utara',
#  'jl.lombok, bintaro',
#  'jalan swadaya, pamulang',
#  'pondok aren',
#  'sektor 8 bintaro jaya, bintaro',
#  'jl perkutut, bintaro',
#  'gramercy alam sutera, alam sutera',
#  'bintaro sektor 2, bintaro',
#  'ciputat lebak bulus cirendeu, ciputat',
#  'jalan karya, ciputat timur',
#  'pondok aren bintaro, bintaro',
#  'paradise resort, ciputat',
#  'bintaro jaya, bintaro',
#  'cluster bohemia gading serpong tangerang, gading serpong',
#  'jl kana 3 bsd, lengkong gudang, serpong, serpong',
#  'griya loka, bsd',
#  'cluster patagonia, de latinos, bsd',
#  'lestari, ciputat',
#  'jl. bohemia raya, gading serpong',
#  'bintaro sektor 7, bintaro',
#  'jalan lele 5, pamulang',
#  'cluster flamingo bintaro jaya sektor 9, bintaro',
#  'discovery bintaro, bintaro',
#  'ciputat, ciputat',
#  'jl.lengkong serpong bsd, bsd',
#  'villa cinere mas, pisangan, ciputat timur',
#  'pamulang',
#  'jl lengkong raya al husainy bsd, bsd',
#  'bintaro sektor 9, bintaro',
#  'kencana loka, bsd',
#  'cluster carissa graha raya, serpong utara',
#  'jl kebon kopi pengasinan gunung sindur, serpong',
#  'jl. pipit kompas, kampung sawah, ciputat, ciputat',
#  'jalan cendana, ciputat timur',
#  'jl. ambon nusa loka, bsd, bsd',
#  'jl. sukamulya raya, serua indah, ciputat',
#  'perumahan bintaro sektor 3, pondok aren',
#  'sektor 1, bintaro',
#  'curug sangereng, tangerang, gading serpong, bintaro',
#  'jalan kebon kopi, ciputat',
#  'jl. bsd boulevard utara, bsd',
#  'savia bsd, bsd',
#  'de nara bsd cityan, bsd',
#  'jl. lkr bumi botanika utara, serpong',
#  'kebayoran symponi, bintaro',
#  'sekolah al azhar bsd, bintaro',
#  'de park bsd, bsd',
#  'jalan raya ciputat parung, pamulang',
#  'puri bintaro, bintaro',
#  'cluster valencia, bintaro',
#  'komp duta loka, pondok aren',
#  'pondok indah, bintaro',
#  'mertilang, bintaro',
#  'camar, bintaro',
#  'jl kampung utan, ciputat',
#  'jalan benda raya, pamulang, pamulang',
#  'menteng utama sektor 7 bintaro jaya, bintaro',
#  'jl cut nyak dien, bintaro',
#  'jl. kemuning 3 pamulang barat, pamulang',
#  'cluster eldora, serpong utara',
#  'jl. ciwaru tenjo tangerang, serpong',
#  'jl. merak no. 10b komplek pajak jurangmangu timur, bintaro',
#  'jl. legoso ciputat, ciputat timur',
#  'bintaro sektor 8, bintaro',
#  'nusaloka, bsd',
#  'jl. canossa, pondok aren',
#  'cijantra, pagedangan, tangerang, bsd',
#  'nusaloka, serpong',
#  'vinca, bsd',
#  'jalan sawo, pondok benda, pamulang, pamulang',
#  'pamulang, pamulang',
#  'graha raya bintaro, bintaro',
#  'pondok aren, pondok aren',
#  'green serpong bintaro, serpong',
#  'bintaro sektor 3a, bintaro',
#  'jl. palapa sarua, ciputat, ciputat',
#  'jl. bratasena v no.10, pamulang',
#  'jl.lkr bumi botanika utara, serpong',
#  'the icon, bsd',
#  'jl.benda 11,pamulang 2,tangsel, alam sutera',
#  'jl.benda 11,pamulang 2,tangsel, serpong',
#  'jl.benda 11,pamulang,tangsel, pondok aren',
#  'jl.benda 11,pamulang 2,tangsel, ciputat',
#  'jl.benda 11,benda 2, tangsel, pamulang',
#  'jl.benda 11,tangsel, bsd',
#  'jl benda 11,pamulang 2,tangsel, ciputat',
#  'jl.benda 11,pamulang 2, tangsel, ciputat timur',
#  'jl.benda 11,pamulang 2,tangsel,, alam sutera',
#  'jl.benda 11,pamulang 2,tangsel, ciputat timur',
#  'jln kebon kopi, pamulang',
#  'bsd city, gading serpong',
#  'bsd city, pondok aren',
#  'jln kebon kopi gg betet, alam sutera',
#  'jln kebon kopi pengasinan, serpong',
#  'cluster celesta, serpong utara',
#  'jl. benda pamulang, pamulang',
#  'jl. alam utama, rt.002/rw.003, pakualam, serpong utara',
#  'medang, pagedangan, gading serpong, bsd',
#  'gading serpong, serpong utara',
#  'emerald bintaro, pondok aren',
#  'jl. danau maninjau, bsd',
#  'jl red diamond, lengkong gudang, serpong, serpong',
#  'fortune spring graha, ciputat',
#  'nara village, jalan proklamasi, gading serpong, tangerang, gading serpong',
#  'jopos graha lestari, pondok aren',
#  'kebayoran residence, bintaro',
#  'jalan garuda, pondok aren',
#  'kebayoran bintaro sektor 7, bintaro',
#  'cluster gading serpong, gading serpong',
#  'flo residence, ciputat timur',
#  'jl. bumi botanika, serpong',
#  'fortune garden, bintaro',
#  'jl. pondok hijau golf raya gading serpong, gading serpong',
#  'jalan gandasasmita, ciputat',
#  'jombang raya, ciputat',
#  'plumeria gr 23, pondok aren',
#  'jl elang, bintaro',
#  'jl bintaro jaya sektor 9 -taman puri bintaro, bintaro',
#  'jl cirendeu raya, ciputat timur',
#  'derio, serpong',
#  'bintaro jaya sektor 5, bintaro',
#  'bintaro pondok ranji, bintaro',
#  'discovery bintaro jaya sektor 9, bintaro',
#  'bintaro jayasektor 5, bintaro',
#  'bintaro jaya sektor 9, bintaro',
#  'dekat mall  bintaro plaza, bintaro',
#  'bintaro jaya sektor 3deket mall plaza bintaro, bintaro',
#  'jl nusa, bintaro',
#  'discovery bintaro sektor 9, bintaro',
#  'pinguin, bintaro',
#  'gelatik, bintaro',
#  'pisok, bintaro',
#  'cucur, bintaro',
#  'fortune, bintaro',
#  'jl. kemang, buaran, serpong, serpong',
#  'jl. alip gede, serua, ciputat, ciputat',
#  'jl cilalung 3 jombang, ciputat, ciputat',
#  'provence parklan, bsd',
#  'icon bsd city, bsd',
#  'cluster edelweis, bsd',
#  'greenwich, bsd',
#  'jalan ciputat, ciputat',
#  'icon cosmo, bsd',
#  'jl. sutra, alam sutera',
#  'jalan garuda kencana, bsd',
#  'ciater bsd tangerang selatan banten, bsd',
#  'jalan palapa, serpong',
#  'dekat rc veteran jaksel, bintaro',
#  'graha raya bintaro, serpong utara',
#  'lengkong gudang, kec. serpong, kota tangsel, bsd',
#  'jl. puspitek raya, serpong',
#  'tangerang selatan, bintaro',
#  'jl bulak wangi, ciputat timur',
#  'jl.mertilang bintaro jaya sektor 9, bintaro',
#  'griya mm 12, ciputat',
#  'serpong city paradise cluster rasamala, serpong',
#  'pondok aren residence, pondok aren',
#  'pondok jati residence, pondok aren',
#  'jl. kesadaran, pamulang',
#  'jl nusa loka, bsd',
#  'perumahan cendana green village, pamulang',
#  'serpong lagoon cluster pelican, setu',
#  'bintaro raya, ciputat,pondok aren, bintaro',
#  'villa dago pamulang, pamulang',
#  'jl.rawa buntu, serpong, bsd, bsd',
#  'pondok ranji, bintaro tangsel, bintaro',
#  'palem puri bintaro, bintaro',
#  'bintaro, pondok aren',
#  'jl. melati 1, blok b2/14, kedaung ciputat, ciputat',
#  'golden, bsd',
#  'kencanaloka, bsd',
#  'nusaloka, bsd, bsd',
#  'gn. sindur, serpong',
#  'jl garuda, pamulang',
#  'foglio, foresta, bsd',
#  'jl raya pinang, pamulang',
#  'serpong estate, bsd',
#  'kencanaloka ext, bsd, bsd',
#  'vila dago pamulang, pamulang',
#  'sutera narada nykka, alam sutera',
#  'sutera narada serpong, alam sutera',
#  'binataro sektor 3, bintaro',
#  'pondok cabe, pamulang',
#  'sektor 3, bintaro',
#  'jalan h isa, ciputat timur',
#  'jl raya serpong, serpong',
#  'vila cendana, cempaka putih, ciputat timur, ciputat',
#  'jalan lele bambu apus, pamulang',
#  'rumah jalan raya di depan alfamart, ganesha raya, pamulang',
#  'witana harja, pamulang',
#  'jl suka mulya, ciputat',
#  'jln bellagio, serpong, tangsel, bsd',
#  'jl. jombang raya jombang, ciputat, ciputat',
#  'lengkong wetan, serpong',
#  '. jl. sumatera bintaro terrace 2 tangerang selatan, serpong',
#  'jl lengkong wetan bsd, bsd',
#  'jl lengkong karya bsd, bsd',
#  'bintaro sektor 3a, pondok aren',
#  'jl lengkong wetan, serpong',
#  'pondok aren, bintaro',
#  'alam sutera, alam sutera',
#  'nusa loka park, bsd',
#  'jl. dewi sartika no.34, ciputat, kec. ciputat, kota tangerang selatan, ciputat',
#  'cluster swadaya tangsel, pondok aren',
#  'jl. bukit permata pamulang tangsel, pamulang',
#  'jl. raya cisauk, serpong',
#  'gading serpong, bsd',
#  'graha raya cornelia, serpong utara',
#  'jl. komp. puri bintaro, ciputat',
#  'jl.palapa sarua, ciputat, ciputat',
#  'discovery, bintaro',
#  'jl raya cireundeu, ciputat timur',
#  'perum banjar wijaya tangerang, ciputat',
#  'bsd, serpong, tangsel dekat stasiun rawa buntu, alam sutera',
#  'bali resort serpong, bsd',
#  'the green bsd city cluster blossomville, bsd',
#  'jalan ruby residence one, bsd',
#  'jalan taman edelweis, bsd',
#  'nusa jaya pondok ranji bintaro, bintaro',
#  'graha raya, pondok aren',
#  'jl.deplu utama pondok aren, bintaro',
#  'jalan granada, gading serpong',
#  'puri bintaro sektor 9, bintaro',
#  'kucica bintaro sektor 9, bintaro',
#  'puri  bintaro sektor 9, bintaro',
#  'maleo bintaro sektor 9, bintaro',
#  'permata bintaro sektor 9, bintaro',
#  'kebayoran residence bintaro sektor 7, bintaro',
#  'pamulang estate, pamulang',
#  'jalan emerald, gading serpong',
#  'villa pamulang, pamulang',
#  'jl rusa iv, bintaro',
#  'bintaro jaya sektor 4 jl.cucur bintaro, bintaro',
#  'bintaro - pondok ranji, bintaro',
#  'pandawa 5 pamulang, pamulang',
#  'jl.graha raya bintaro, bintaro',
#  'deplu pondok aren, pondok aren',
#  'graha raya bintaro cluster eldora, bintaro',
#  'jl. raya cendana rawakalong, serpong, serpong',
#  'jl. raya cendana rawakalong, pamulang, pamulang',
#  'grand bulevard, bsd city, bsd',
#  'setu',
#  'villa inti persada, pamulang',
#  'caribean island, bsd',
#  'jalan lengkong gudang serpong bsd city, bsd',
#  'jalan mandar raya bintaro sektor 3a tangerang sel, bintaro',
#  'bintaro banten, bintaro',
#  'ciaterbsd, serpong tangerang selatan banten, serpong',
#  'jalan palapa,ciater,ciputat,tangerang selatan, bsd',
#  'jalan palapa,ciater,ciputat,tangerang selatan, serpong',
#  'gading serpong tangerang selatan, gading serpong',
#  'jl bhakti ciputat, ciputat',
#  'grand akasia tangerang, pondok aren',
#  'bintaro sektor 6, bintaro',
#  'bintaro hill, bintaro',
#  'jurangmangu timur, pondok aren',
#  'grah raya bintaro, serpong utara',
#  'the orchid bintaro, bintaro',
#  'bintaro sektor 5, bintaro',
#  'jl molek vi, ciputat',
#  'jl kebon kopi pengasinan gunung sindur, bintaro',
#  'jalan raya serua ciputat, ciputat',
#  'jalan raya puspitek serpong, serpong',
#  'villa cinere mas, ciputat timur',
#  'jl kademangan, setu, tangsel, setu',
#  'jl. pahlawan, ciputat',
#  'jl abdul gani, ciputat',
#  'milano village, gading serpong',
#  'jl. pinang raya rt. 002 rw. 022 pamulang timur, pamulang',
#  '10 jl. ki hajar dewantara, ciputat',
#  '33 pdk.cempaka rt.03,rw.10, rempoa, ciputat timur,tangsel, bintaro',
#  'jl raya puspitek - pamulang, pamulang',
#  '12 jl raya southcity utara, lot 5, pamulang',
#  'jl benda raya, pamulang',
#  'jl.inpres, rt 02/ rw 09, pamulang',
#  'jl benosa, serpong',
#  '99 jalan raya pengasinan, bsd',
#  '26 jl. kunir, pd. cabe udik, pamulang',
#  'jalan provence suites, bsd',
#  'lengkong banten tangerang selatan, bsd',
#  'samara village, jl jend.gatot subroto,tangerang, gading serpong',
#  'pisangan, ciputat',
#  'graha raya, bintaro',
#  'menteng raya, bintaro',
#  'les belles, serpong',
#  'serpong, bsd',
#  'bougenville, pondok aren',
#  'cluster bintaro resident, bintaro sektor 7, bintaro',
#  'cluster prime bintaro, bintaro',
#  'villa gunung lestari, bintaro',
#  'cluster gardenia loka, graha bintaro, pondok aren',
#  'dahlia loka, bintaro',
#  'callysta graha bintaro, bintaro',
#  'jl. pendidikan raya - rawa kalong serpong, serpong',
#  'jln mandar, bintaro',
#  'pondok ranji, ciputat timur',
#  'sektor 9 bintaro, bintaro',
#  'ciputat tim., kota tangerang selatan, ciputat timur',
#  'jln kebayoran harmony bintaro, bintaro',
#  'rumah dijual discovery bintaro jaya sektor 9, pondok aren',
#  'kebayoran view bintaro jaya, bintaro',
#  'jalan raya sektor 9, serpong utara',
#  'jalan raya bintaro jaya sektor 9, bintaro',
#  'ruma dijuak discovery bintaro jaya sektor 9, serpong utara',
#  'kebayoran village bintaro, bintaro',
#  'jln.lele 5 pamulang, pamulang',
#  'jl.raya kadu sirung, pagedangan tangerang banten, alam sutera',
#  'jl.raya kadu sirung, pagedangan tangerang banten, bsd',
#  'camar bintaro, bintaro',
#  'jl intan ii, setu',
#  'jalan sumatera ruko, bintaro terrace 2 no.8, bintaro',
#  'jl raya permata rawakalong bsd, pamulang',
#  'jl raya bukit dago, pamulang',
#  'jln boulevard bintaro jaya, bintaro',
#  'bumi botanika utara lengkong pagedangan tangerang, bsd',
#  'cirendeu, ciputat',
#  'jl. inpres, pamulang',
#  'cisauk, tangerang regency, bsd',
#  'kencana hill residence blok a no 10 ciater serpong, serpong',
#  'jalan oscar raya, ciputat timur',
#  'jalan viktor raya dekat kampus unpam 2, serpong',
#  'green serpong bintaro blok e no 6, serpong',
#  'jl taman parangtritis, pamulang barat, pamulang, pamulang',
#  '. jl. elang iv, kel. sawah lama, ciputat',
#  'jl. kelurahan buaran, buaran, serpong',
#  'green serpong bintaro, bsd',
#  'jl h. abdul gani, cempaka putih, ciputat timur',
#  'perumahan villa mutiara, serpong',
#  'the eminent vivacia, serpong',
#  'jl siliwangi, pamulang, tangsel, pamulang',
#  '. jl. taman fasco rt.004 rw.004 serua, ciputat',
#  'jalan monaco, gading serpong',
#  'greenwich bsd, bsd',
#  'cluster malibu village bsd tangerang, bsd',
#  'jalan flourite, gading serpong',
#  'delatinos bsd city, bsd',
#  'kencana loka bsd city, bsd',
#  'the green bsd, bsd',
#  'vanya park bsd city, bsd',
#  'the green bsd city, bsd',
#  'jalan sektor 7c, gading serpong',
#  'jalan inpres, pamulang',
#  'jalan masjid ciater serpong tangsel, serpong',
#  'jalan masjid ciater serpong, serpong',
#  'jalan pondok sentul no 45 serpong tangsel, serpong',
#  'cisauk, serpong',
#  'cluster cosmo the icon bsd city, bsd',
#  'jalan sektor 1 c, gading serpong',
#  'reni jaya, pamulang',
#  'pandawa 5, pamulang',
#  'jln.lele 5, pamulang',
#  'ciater raya, serpong',
#  'bukit serpong mas, serpong utara',
#  'jl.kebon kopi pengasinan gunung sindur, bsd',
#  'jalan bohemia, gading serpong',
#  'boulevard, gading serpong',
#  'vinaya terrace bintaro, bintaro',
#  'perkici bintaro jaya sektor 5, bintaro',
#  'jl. jambu - kompl jambusaripisangan ciputat, ciputat timur',
#  'bukit nusa indah, ciputat',
#  'jalan raya pamulang-siliwangi, ciputat',
#  'jalan puspiptek, pamulang',
#  'jalan boulevard gading serpong, gading serpong',
#  'cluster malibu village, bsd',
#  'illago gading serpong, serpong utara',
#  'jalan illago boulevard gading serpong, gading serpong',
#  'jalan malibu village gading serpong bsd tangerang, gading serpong',
#  'jalan boulevard gading serpong symphonia tangerang, gading serpong',
#  'cluster omaha village illago serpong, serpong utara',
#  'cluster amarillo village gading serpong, serpong',
#  'cluster atlanta village gading serpong, gading serpong',
#  'graha raya cornelia residence, bintaro',
#  'jalan raya kelapa dua gading serpong, gading serpong',
#  'jalan bintaro jaya sektor 9 tangerang selatan, bintaro',
#  'jalan boulevard matera gading serpong, gading serpong',
#  'jl. proklamasi, gading serpong',
#  'jalan gading serpong boulevard, bsd',
#  'jalan boulevard illago gading serpong tangerang, bsd',
#  'cluster malibu village gading serpong, gading serpong',
#  'jalan illago boulevard gading serpong, serpong',
#  'jalan ir sukarno il lago gading serpong, gading serpong',
#  'malibu village gading serpong, gading serpong',
#  'cluster amarillo village, bsd',
#  'cluster omaha village gading serpong, pamulang',
#  'cluster pasadena, bsd',
#  'cluster matera residence gading serpong, serpong',
#  'jalan boulevard gading serpong, bsd',
#  'jl. bsd raya pusat, serpong',
#  'boluevard gading serpong, gading serpong',
#  'sutera tiara, alam sutera',
#  'pascal barat, alam sutera',
#  'sutera sitara, alam sutera',
#  'grand akasia, pamulang',
#  'sutera feronia, alam sutera',
#  'pelangi boulevardd, alam sutera',
#  'feronia tamann, alam sutera',
#  'sutera olivia boulevard, alam sutera',
#  'sektor 9 puri bintaro jaya, bintaro',
#  'jalan british, gading serpong',
#  'jalan samara, gading serpong',
#  'jalan pascal, gading serpong',
#  'jalan chysocolla, gading serpong',
#  'jalan sektor 8, gading serpong',
#  'jl. discovery blvd, pondok aren',
#  'jl. boulevard bintaro jaya, pondok aren',
#  'jl. discovery aluvia, pondok aren',
#  'jl. bintaro utama 10, pondok aren',
#  'jl. kby. residences, pondok aren',
#  'jl. sisingamangaraja, pondok aren',
#  'jl. hr rasuna said discovery residences, pondok aren',
#  'jl. hr rasuna said discovery residences bintaro, pondok aren',
#  'jl. discovery park, pondok aren',
#  'lkr bumi botanika utara lengkong tangerang, bsd',
#  'serpong city paradise cluster rasamala, setu',
#  'alana signature serpong, serpong',
#  'alana signature serpong, pondok aren',
#  'alana signature serpong, pamulang',
#  'satu-satunya kavling siap bangun di pamulang, pamulang',
#  '081285153957 gading serpong, gading serpong',
#  'jl intan, ciputat',
#  'jl serpong raya, ciputat',
#  'jl pesantern, pondok aren',
#  'jl raya cirendeu, ciputat timur',
#  'pesantren, pondok aren',
#  'serpong, gading serpong',
#  'serpong, ciputat timur',
#  'serpong, ciputat',
#  'serpong, bintaro',
#  'rempoa, ciputat',
#  'sektor 2, bintaro',
#  'jl. garuda 5 villa pamulang, pamulang',
#  'jl.walet  jurang mangu barat, pondok aren',
#  'jl, walet raya jurang mangu barat, pondok aren',
#  'berseberangan dengan vanya park dan branchsto bsd, bsd',
#  'jalan pesantren jurang mangu bintaro, pondok aren',
#  'pondok kacang tangerang selatan, pondok aren',
#  'paradise serpong city, serpong',
#  'jalan raya sawangan, pamulang',
#  'bsd kencana loka, bsd',
#  'jelupang, serpong',
#  'pondok kacang barat, pondok aren',
#  'kencana loka 12.5 bsd city, bsd',
#  'cirendeu, ciputat, ciputat',
#  'pisangan, kec. ciputat tim.,tangerang selatan, ciputat timur',
#  'jln pondok benda pamulang, pamulang',
#  'jln swadaya pondok benda pamulang, pamulang',
#  'kucica bintaro jaya sektor 9, bintaro',
#  'pasadena residence, gading serpong',
#  'jl pelita, pamulang',
#  'bintaro jaya sektor 2, bintaro',
#  'bintaro area sektor 1 jakarta selatan, bintaro',
#  'kasuari bintaro jaya, bintaro',
#  'jalan mozart, gading serpong',
#  'jln kebon kopi, serpong',
#  'jl.kodiklat tni ampera, serpong',
#  'jl.sumatera, ciputat',
#  'jl kebon kopi pengasinan gunung sindur, bsd',
#  'cluster discovery, bintaro jaya sektor 9, bintaro',
#  'jl serua ciputat, ciputat',
#  'jl. serua, ciputat',
#  'jl. kesehatan v, ciputat timur',
#  'jl. bendaraya, pamulang',
#  'rempoa raya, ciputat timur',
#  'pamulang , pamulang',
#  'less belles mansion, bsd',
#  'bintaro jaya sektor 3, bintaro',
#  'jl. buaran - rawa buntu, bsd',
#  'jl. ciater barat, serpong',
#  'jl. raya terusan rawa buntu - victor - ciater, serpong',
#  'jl. swadaya, ciater , serpong - tangerang selatan, serpong',
#  'jalan legoso ciputat tangsel, ciputat timur',
#  'jalan raya bsd, bsd',
#  'jl. babakan poris, pamulang',
#  'jl. discovery terra , parigi, kec. pd. aren, pondok aren',
#  'perum al falaah 3 pamulang, pamulang',
#  'jalan kelapa hybrida, gading serpong',
#  'jalan de latinos, bsd',
#  'jalan precia, bsd',
#  'jalan omaha, gading serpong',
#  'sektor 1 a, gading serpong',
#  'jalan nusaloka, bsd',
#  'jalan baroni, gading serpong',
#  'jalan sektor 6, gading serpong',
#  'jalan askara, bsd',
#  'jalan griya sutera, alam sutera',
#  'maleo, bintaro',
#  'jalan bsd tangerang selatan, bsd',
#  'jalan crystal, gading serpong',
#  'jalan griyaloka, bsd',
#  'mahagoni park bintaro jaya, bintaro',
#  'ciputat tangerang selatan, ciputat',
#  'ciputat, bintaro',
#  'jl. raya ciputat parung, ciputat',
#  'elang bintaro, bintaro',
#  'h. saiyan, bintaro',
#  'frangipani de park bsd, bsd',
#  'faraday, gading serpong',
#  'terrace golf bsd, bsd',
#  'jl alam sutera boulevard alam sutera, serpong utara, serpong utara',
#  'emerald bintaro sektor 9, bintaro',
#  'bahamas delatinos bsd, bsd',
#  'kebayoran bintaro.jaya 7, bintaro',
#  'cluster faraday, gading serpong',
#  'the zora, bsd',
#  'sektor 5 bintaro jaya, bintaro',
#  'bintaro jaya sektor 4, bintaro',
#  'perumahan bukit dago, serpong',
#  'graha raya, cornelia residence cr b02, serpong utara',
#  'graha jeumpa 2, setu',
#  'fortune belleza, pondok aren',
#  'jalan salak, pamulang',
#  'jalan rusa, bintaro',
#  'jalan rusa no. 111 tangerang selatan, bintaro',
#  'villa inti persada, jl. halmahera blok c9 no 1, pamulang',
#  'natura cattleya, setu',
#  'jalan h som, pondok aren',
#  'magnolia griya loka bsd, bsd',
#  'sektor 3a bintaro pondok aren tangerang selatan, bintaro',
#  'pinus rt 002 rw 020 pamulang timur tang selatan, pamulang',
#  'bukit nusa indah, jl. kembang sepatu no. 377b, ciputat',
#  'graha jeumpa 2, pamulang',
#  'jln lestaro, pamulang',
#  'jln.villa pamulang, pamulang',
#  'lestari, pamulang',
#  'jl h.embha, pamulang',
#  'jl ir. h. juanda, cirendeu, ciputat timur',
#  'jl.lombok sumatra tangsel, bintaro',
#  'golden park bsd serpong, bsd',
#  'discovery conserva bintaro sektor 9, bintaro',
#  'discovery lumina bintaro sektor 9, bintaro',
#  'jl.sutra jelita utama no 2 serpong utara, alam sutera',
#  'jl. ciater wareng rawakalong, serpong, serpong',
#  'jl. raya lestari, pamulang, pamulang',
#  'jl. masjid al amin, pamulang',
#  'jl. h. sawil, jombang, ciputat',
#  'jl. merpati raya, kp sawah lama, ciputat',
#  'jl. amd v, bintaro',
#  'jl. jombang raya, bintaro',
#  'jl. bambu apus, pamulang',
#  '. jl. palem puri no.40, jombang, ciputat, kota tange, bintaro',
#  'jl. jombang raya, pondok aren',
#  'kp. rawa barat, pondok pucung, bintaro',
#  'jl. lengkong gudang timur bsd tangerang selatan, bsd',
#  'jl. rusa iv no. 111, pondok ranji, ciputat timur',
#  'jl. kucica, bintaro',
#  'jl. bukit indah, ciputat',
#  'jl. cendrawasih v sawah baru, bintaro',
#  'jl. h. cari, pd. kacang barat, bintaro',
#  'jl.jombang raya, bintaro',
#  'jl. h. jamat, serpong',
#  'jl.kp rawa barat, bintaro',
#  'bambu apus, pamulang',
#  'jalan raya puspitek muncul serpong, pamulang',
#  'jl.baitis salmah, bintaro',
#  'jl. puri indah, bintaro',
#  'jl. kinayungan, bintaro',
#  'jalan raya puspitek serpong, pamulang',
#  'jalan raya muncul puspitek serpong, serpong',
#  'jalan raya puspitek serpong pamulang, serpong',
#  'bsd tangerang, bsd',
#  'kelapa molek, serpong',
#  'sektor 9 bintaro jaya, bintaro',
#  'jl raya terusan phg, curug singereng, serpong, serpong',
#  'jalan camar, bintaro',
#  'cluster mahogany, bintaro',
#  'pondok ranji, bintaro',
#  'sektor, bintaro',
#  'villa bintaro regency, pondok aren',
#  'mahogany, pondok aren',
#  'villa melati mas, serpong utara',
#  'discovery park, bintaro',
#  'teuku umar, bintaro',
#  'nusa jaya pondok ranji ciputat timur, ciputat timur',
#  'cirendeu, ciputat timur - tangerang selatan, ciputat timur',
#  'kasan adl 085702645852, bintaro',
#  'ciputat cipayung, ciputat timur',
#  'jl taman fasco ciputat tangsel., ciputat',
#  'jl taman fasco tangerang selatan, pondok aren',
#  'jalan kereta kencana 3 blok a no. 33, bsd',
#  'cluster green cove, bsd',
#  'jl. sutera onyx xii/20, alam sutera',
#  'cucur timur xvi, bintaro',
#  'jl. hasyim ashari, ciledug, ciledug',
#  'boulevard gading seprong, gading serpong',
#  'boulevard symphonia summarecon serpong, gading serpong',
#  'symphonia summarecon serpong, gading serpong',
#  'boulevard symphonia summarecon seprong, bsd',
#  'boulevard symphonia serpong, gading serpong',
#  'jalan boulevard bsd, bsd',
#  'bambu apus pamulang tangsel, pamulang',
#  'jalan villa dago raya, pamulang',
#  'jalan sawo pamulang tangerang selatan, pamulang',
#  'jln.amd .pocis serpong, serpong',
#  'pondok jaya  bintaro sek.3, bintaro',
#  'pocis bakti jaya serpong, serpong',
#  'cluster graha mas serpong utara, serpong utara',
#  'serua ciputat, ciputat',
#  'the spring, serpong',
#  'rumah inti persada, pamulang',
#  'jln.bukit permata, serpong',
#  "jln raya vila dago sd al'azhar, pamulang",
#  'benda barat 2, pamulang',
#  'jln jeruk raya, ciputat timur',
#  'bukit permata, serpong',
#  'jln.anggur, ciputat timur',
#  'jln.percik bintaro sektor 5, bintaro',
#  'jln pondok ranji ciputat, ciputat',
#  'jln .witanaharja pamulsng, pamulang',
#  'jl kuricang ciputat timur tangerang selatan, ciputat timur',
#  'discovery residence, bintaro',
#  'bintaro sektor 1, bintaro',
#  '. jl. jombang astek, jombang, serpong',
#  'jl raya siliwangi (jl lurah), pamulang, pamulang',
#  'melati mas, serpong',
#  'kencanaloka bsd, bsd',
#  'alam sutra, alam sutera',
#  'delatinos bsd, bsd',
#  'the icon bsd city, bsd',
#  'jalan bintaro, bintaro',
#  'bintaro sektor 2, bintaro pondok ranji, bintaro',
#  'bintaro tangerang selatan, bintaro',
#  'discovery aluvia bintaro jaya sektor 9, bintaro',
#  'jurang mangu tangsel, bintaro',
#  'discovery amore bintaro jaya sektor 9, bintaro',
#  'cluster bintaro jaya, bintaro',
#  'discovery eola bintaro jaya sektor 9, bintaro',
#  'cluster kebayoran bintaro, bintaro',
#  'new serpong estate, pamulang',
#  'the green, de park,  bsd city tangerang, bsd',
#  'deplu bintaro, bintaro',
#  'bintaro jaya tangerang selatan banten, bintaro',
#  'bintaro boulevard, bintaro jaya, bintaro',
#  'bintaro sektor 3, bintaro',
#  'graha raya bintaro, graha raya boulevard, bintaro',
#  'haji rabun, ciputat',
#  'emerald bintaro, bintaro sektor 9, bintaro',
#  'pamulang tangerang selatan, pamulang',
#  'jalan sutera utama alam sutera tangerang, alam sutera',
#  'cluster foresta collinare-khusus buyer langsung, bsd',
#  'kebayoran bintaro, bintaro',
#  'jl. pondok petir raya no.99, pamulang',
#  'cucur bintaro, bintaro',
#  'jombang bintaro, bintaro',
#  'sektor 12.3, serpong',
#  'griyaaloka, serpong',
#  'jalan oscar raya, bintaro',
#  'menteng bintaro, bintaro',
#  'jalan oscar raya, pamulang',
#  'jalan oscar raya, ciputat',
#  'cirendeu raya, ciputat timur',
#  'jalan oscar raya, setu',
#  'jl legoso, ciputat, ciputat timur',
#  'jl. serpong raya, pengasinan, serpong',
#  'jl benda, ciputat',
#  'jalan symphonia boulevard, gading serpong',
#  'the springs summarecon serpong, bsd',
#  'bsd, serpong, tangsel dekat stasiun rawa buntu, bintaro',
#  'bsd, serpong, tangsel dekat stasiun rawa buntu, pondok aren',
#  'icon cosmo bsd-khusus buyer, bsd',
#  'cikini ii sektor 5 bintaro jaya tangerang selatan, bintaro',
#  'jl. raya puspitek, pamulang',
#  'jl. kby. residence, pd. aren, kec. pd. aren, pondok aren',
#  'kebayoran harmony bintaro cluster nordic, pondok aren',
#  'jalan oscar raya,, pamulang',
#  'pondok kacang, pondok aren',
#  'bintaro jaya sektor 9 maleo, bintaro',
#  'villa  bintaro indah, bintaro',
#  'bintaro sektor 3 jalan camar, bintaro',
#  'pelikan sektor 2 bintaro jaya tangerang selatan, bintaro',
#  'komplek puri bintaro hijau, pondok aren',
#  'villa melati mas, bsd',
#  'jln inpres pamulang belakang villa dago, pamulang',
#  'jln. pahlawan raya, ciputat, tangsel, ciputat timur',
#  'jampang gunung sindur, pamulang',
#  'boulevard bintaro jaya, bintaro',
#  'boulevard bsd, bsd',
#  'jln.inpres pamulang, ciputat',
#  'jurangmangu, pondok aren',
#  'serpong, setu',
#  'taman giri loka, serpong',
#  'jln. pondok benda pamulang, ciputat',
#  'jln swadaya pamulang, pamulang',
#  'jlmn. pondok  benda pamulang, pamulang',
#  'kucica sektor 9 bintaro tanggerang selatan, bintaro',
#  'jl.galur cirendeu pisangan ciputat, ciputat',
#  'jln.swadaya ,pondok benda pamulang, pamulang',
#  'jalan raya ciputat, ciputat',
#  'lestari pamulang, pamulang',
#  'jalan palapa raya, ciputat',
#  'jalan palapa  raya, serpong',
#  'jalan raya  palapa raya, bsd',
#  '. jl. w r supratman blok k no.15, ciputat, ciputat',
#  'jln. lestari pamulang, pamulang',
#  'jl.jombang raya/vila bintaro indah /tang- sel, bintaro',
#  'jalan komplek perumahan nusa loka bsd serpong, bsd',
#  'jalan pahlawan, pamulang',
#  'jaln pendidikan, pamulang',
#  'jln surya kencana, pamulang',
#  '. jl. kesadaran, pamulang',
#  '. jl. puspitek, pamulang',
#  '. jl. h. nawi malik, serpong',
#  '. jl. raya puspiptek, pamulang',
#  'jl. pendidikan., pamulang',
#  'jl. parung ciseeng, pamulang',
#  'jl.deplu pondok aren, bintaro',
#  'jl jalan kesadaran pindok petir, ciputat',
#  'jl.pamulang raya, pamulang',
#  'jl.ceger raya pondok aren tangerang selatan, bintaro',
#  'jln parung ciseeng, serpong utara',
#  'jl.taman permata bintaro sektor 9, bintaro',
#  'jaln kesadran, pondok aren',
#  'jl.rajawali,jl.kasuari,jl.kucica, bintaro',
#  'jl. kesadaran, ciputat',
#  '. jl.kesadaran, ciputat',
#  '. jl.raya rawa buntu, pamulang',
#  'jl. pala raya, cinangka, depok, pamulang',
#  'jln kesadran, pamulang',
#  'jln kesadaran, pamulang',
#  'jalan ds rawa kalong, pamulang',
#  'jln raya vila pamulang, pamulang',
#  'jaln reni jaya, pamulang',
#  'jln .reni jaya, pamulang',
#  '. jl.pendidikan, pamulang',
#  'discovery, pondok aren',
#  'taman puri bintaro sektor 9, bintaro',
#  'cluster callysta residence graha bintaro jaya, bintaro',
#  'jl puyuh, bintaro',
#  'kebayoran residence bintaro jaya sektor 7, bintaro',
#  'wisma pondok aren, bintaro',
#  'discovery serenity, bintaro',
#  'jl. permai tim, jurang mangu barat, pondok aren',
#  'kebayoran residence tangerang selatan, bintaro',
#  'serpong natura city, bsd',
#  'sawah baru, ciputat',
#  'legoso, ciputat',
#  'the green bsd, serpong',
#  'kencana loka bsd, bsd',
#  'jl. pancoran mas, ciputat timur',
#  'jl. garuda 5, villa pamulang, pamulang',
#  'jalan pinus pamulang timur, pamulang',
#  'nerada estate, ciputat',
#  'jl. nias, pondok kacang tim, kec. pondok aren, pondok aren',
#  'jln.lele 5 pamulang, ciputat',
#  'jln.pandawa 5 pamulang, serpong',
#  'jl. discovery park - discovery residences bintaro, bintaro',
#  'delatinos mexicano bsd, bsd',
#  'bintaro jaya sektor 7, bintaro',
#  'bintaro jaya sektor 8, bintaro',
#  'sawah lama ciputat, bintaro',
#  'komplek grand bintaro asri  jl ki hajar dewantara, bintaro',
#  'jl.kihajardewantara kampung sawah ciputat, bsd',
#  'jalan boulevard, bsd',
#  'jl. muri salim, pisangan, kec. ciputat timur, ciputat timur',
#  'lengkong karya, serpong utara',
#  'jl. alamanda b.3. rawa buntu, kec. serpong, serpong',
#  'jln.pandawa 5, pamulang',
#  'jln pandawa 5, pamulang',
#  'jl atmaja, pamulang',
#  'jl.ki saniin no.8a, serpong utara',
#  'bhayangkara pusdiklantas, serpong utara',
#  'foresta raya, bsd',
#  'gading, bsd',
#  'alam cirendeu, ciputat timur',
#  'gading serpong, bsd, alam sutera, gading serpong',
#  'pasadena, gading serpong, alam sutera, bsd',
#  'gading serpong, bsd, alam sutera, pamulang',
#  'bsd, gading serpong, alam sutera, alam sutera',
#  'malibu village, pamulang',
#  'gading serpong, serpong',
#  'jl. pamulang, pamulang',
#  'malibu village gading serpong, bintaro',
#  'cirendeu, ciputat timur',
#  'matera residences gading serpong bsd, serpong',
#  'jl raya pagedangan, gading serpong',
#  'jl krakatau, ciputat',
#  'jl. jombang raya - bintaro tangerang selatan, bintaro',
#  'jl raya pagedangan, bsd',
#  'gading serpong, bintaro',
#  'gading serpong, alam sutera',
#  'jalan discovery park bintaro jaya tangerang selatn, bintaro',
#  'bsd boulevard lengkong kulon pagedangan, bsd',
#  'sektor 5 bintaro, bintaro',
#  'bsd boulevard lengkong kulon pagedangan tangerang, bsd',
#  'jln.cut nyak dien, bintaro',
#  'jln.camar, bintaro',
#  'jalan jalak, bintaro',
#  'nusa jaya, bintaro',
#  'jln.nusa jaya, bintaro',
#  'jln.gelatik blok z no. 6, ciputat',
#  'bintaro raya tengah, bintaro',
#  'jln.merbabu, bintaro',
#  'blok e7 no.2, bsd',
#  'jln.camar 1 bintaro sektor 3, bintaro',
#  'jln.camar vi, bintaro',
#  'sutera alba, alam sutera',
#  'sektor dua, bintaro',
#  'delatinos, bsd',
#  'nava park, bsd',
#  'bintaro, ciputat',
#  'kencan loka, bsd',
#  'jl. cendrawasih no 173, ciputat',
#  'grand boulevard bsd pagedangan tangerang, bsd',
#  'grand boulevard bsd city pagedangan tangerang, bsd',
#  'jln grand boulevard bsd pagedangan tangerang, bsd',
#  'jl boulevard grand bsd pagedangan tangerang, bsd',
#  'jl.raya pondok petir, ciputat',
#  'jl grand boulevard bsd city pagedangan, bsd',
#  'jl bsd grand boulevard lengkong kulon pagedangan, serpong',
#  'jl grand boulevard bsd city pagedangan tangerang, serpong',
#  'jl.kalimantan jombang ciputat, ciputat timur',
#  'menteng utama, bintaro',
#  'grand boulevard bsd city pagedangan, bsd',
#  'bsd city, alam sutera',
#  'jl. proklamasi, gading serpong, tangerang, gading serpong',
#  'cijantra, pagedangan tangerang 15336, serpong',
#  'malibu village paramount cijantran pagedangan, serpong',
#  'jln cijantran pagedangan serpong tangerang, serpong',
#  'kebayoran harmony, bintaro',
#  'bulak wangi ciputat, ciputat',
#  'bulak wangi, ciputat',
#  'bulaki  wangi ciputat, ciputat',
#  'bulak wangi, bintaro',
#  'jl.kebon kopi pengasinan gunung sindur, bintaro',
#  'bintaro sektor 9, pondok aren',
#  'gading serpong tangerang, serpong',
#  'jl.kebon kopi pengasinan gunung sindur, pamulang',
#  'jl. ps jengkol viktor, bintaro',
#  'jl. ps jengkol viktor dekat kampus unpam, bsd',
#  'jl. ps jengkol, viktor dekat unpam 2, ciputat',
#  'jalan sukamulya, bsd',
#  'jalan ps jengkol viktor dekat bsd, ciputat timur',
#  'bintaro sektor 7, pondok aren',
#  'cluster blossomville, the green bsd, bsd',
#  'jalan palapa,ciater,ciputat,tangerang selatan, bintaro',
#  'jalan palapa, bsd',
#  'jln palapa, serpong',
#  'jalan palem puri 1, bintaro',
#  'discovery bintaro sektor 9, pondok aren',
#  'jalan raya pondok aren, pondok aren',
#  'jalan raya boulevard bsd, bsd',
#  'sektor 7 bintaro jaya, bintaro',
#  'pondok aren - tangerang selatan, pondok aren',
#  'delatinos bsd city - tangerang selatan, bsd',
#  'caspia bsd city - tangerang, bsd',
#  'pamulang - tangerang selatan, pamulang',
#  'graha raya bintaro - tangerang selatan, bintaro',
#  'cluster castilla bsd city - tangerang selatan, bsd',
#  'ciputat - tangerang selatan, ciputat',
#  'cluster sanur komplek duta bintaro - tangsel, bintaro',
#  'jurang mangu - tangerang selatan, pondok aren',
#  'serpong jaya - tangerang selatan, bsd',
#  'cluster wellington - tangerang selatan, pamulang',
#  'anggrek loka bsd city - tangerang selatan, bsd',
#  'jalan sumatera, ciputat',
#  'jl. bambu kuning pondok cabe, pamulang',
#  'nykka sutera narada, alam sutera',
#  'jl. puspiptek raya - setu tangerang selatan, setu',
#  'jalan ps jengkol, viktor dekat unpam 2, gading serpong',
#  'ciputat bintaro, ciputat',
#  'regency melati mas serpong, serpong',
#  'jl. lingkar bumi botanika utara, bsd',
#  'jl.ps jengkol dekat unpam 2, pamulang',
#  'jl. sisingamangaraja, pondok jaya, bintaro',
#  'jalan ps jengkol, setu',
#  'jl. kubis, pamulang',
#  'jalan raya pamulang - siliwangi, bintaro',
#  'foresta bsd city serpong, bsd',
#  'rempoa bintaro sektor2 area, ciputat timur',
#  'jl. amarine, bsd',
#  'the green bsd city tangerang selatan, bsd',
#  'jalan muncul muncul, kranggan, kec. setu, bsd',
#  'the icon cosmo bsd city tangerang selatan, bsd',
#  'nusa loka taman crysant 1 bsd, bsd',
#  'grand akasia residence, pamulang',
#  'jalan wortel,bsd city, bsd',
#  'pamulang., pamulang',
#  'jl. dewi sartika, ciputat',
#  'jl bukit indah, ciputat',
#  'jalan raya pondok cabe, ciputat',
#  'jl. ir.sukarno,curug sangereng,gading serpong, bsd',
#  'jalur pipa gas, serua, ciputat, ciputat',
#  'jln lestari pamulang, pamulang',
#  'villa bintaro indah, bintaro',
#  'jln kh ahmad sayani tanah sareal, pondok aren',
#  'jalan. amd pamulang, setu',
#  'jl. karya utama ( jl.elang ) area sektor ix, bintaro',
#  'discovery flamine, bintaro',
#  'lengkong wetan serpong bsd, bsd',
#  'vinaya  terrace bintaro, bintaro',
#  'puri delima asri, ciputat timur',
#  'discovery conserva, bintaro',
#  'kencana raya, serpong',
#  'kom.arinda permai 1, bintaro',
#  'jl.pinus, pamulang',
#  'ciputat raya, ciputat',
#  'jalan pln, pondok aren',
#  'perumahan pamulang lestari blok i pamulang, pamulang',
#  'parigi bintaro, sektor 9, bintaro',
#  'jadeite, bsd, bsd',
#  'rumah residence one, serpong utara',
#  'cilosari sektor 6 bintaro jaya tangerang selatan, bintaro',
#  'jalan perkici, bintaro',
#  'jl bumi foresta, bsd',
#  'medang, kabupaten tangerang, bsd',
#  'jalan viktor, babakan dekat unpam 2, serpong utara',
#  'south city pondok cabe, ciputat timur',
#  'jln. visana the savia ciater serpong, serpong',
#  'jl. raya prada samlawi, putat nutug, ciseeng, serpong',
#  'jl. elang bintaro sektor 9, bintaro',
#  'jalan viktor, babakan dekat kampus unpam 2, serpong',
#  'lombok tangsel, bintaro',
#  'cihuni, pagedangan, tangerang, bsd',
#  'jalan discovery park bintaro, bintaro',
#  'jl elang bintaro sek 9, bintaro',
#  'perumakan lestari cirendeu ciputat, ciputat',
#  'rengas ciputat timur, ciputat timur',
#  'gading serpong - tangerang, gading serpong',
#  'jl. kebayoean residence bintaro tangrang selatan, bintaro',
#  'nusa loka bsd city - tangerang selatan, bsd',
#  'curug sangereng, tangerang, gading serpong, bsd',
#  'jl. discovery park, parigi, kec. pd. aren, bintaro',
#  'cluster vineyard, bsd',
#  'cluster sevilla bsd city - tangerang selatan, bsd',
#  'ciputat bintaro tangerang selatan, bintaro',
#  'jalan puri bintaro 15413, bintaro',
#  'sutera asri boulevard, alam sutera',
#  'lyndon drive, bsd',
#  'sutera sitara jingga orlanda, alam sutera',
#  'sutera feronia park, alam sutera',
#  'onyx 5, alam sutera',
#  'palmyra boulevard, alam sutera',
#  'matera, gading serpong',
#  'pondok jaya, bintaro',
#  'precia, bsd',
#  'cluster orlanda, alam sutera',
#  'jalan haji emba, pamulang',
#  'jalan poncol indah, ciputat',
#  'sutera renata boulevard, alam sutera',
#  'jalan precia utama, bsd',
#  'eminemt bsd, bsd',
#  'jombang sudimara, bintaro',
#  'serpong lagoon, setu',
#  'jalan haji rabun, ciputat',
#  'hylands greenwich park, bsd',
#  'jl. lengkong kulon, pagedangan, pagedangan',
#  'assana vanya park, bsd',
#  'serenade lake, gading serpong',
#  'vermont parkland, gading serpong',
#  'jl bsd, lengkong gudang, serpong, serpong',
#  'mayfield greenwich park, bsd',
#  'kebayoran symphony, bintaro',
#  'pelican, gading serpong',
#  'jl re martadinata cipayung ciputat tangsel, ciputat',
#  'kebayoran harmony bintaro, bintaro',
#  'puri town house, bintaro',
#  'bukit nusa indah, bsd',
#  ...]

# %%
location_df
# Out:
#       listing-location     subdistrict
# 0       gading serpong  gading serpong
# 1       gading serpong  gading serpong
# 2       gading serpong  gading serpong
# 3       gading serpong  gading serpong
# 4       gading serpong  gading serpong
# ...                ...             ...
# 29415          bintaro         bintaro
# 29416          bintaro         bintaro
# 29417          bintaro         bintaro
# 29418          bintaro         bintaro
# 29419          bintaro         bintaro
#
# [23943 rows x 2 columns]

# %%
location_df['subdistrict'] = location_df['listing-location'].apply(
    lambda x: x.rpartition(',')[-1].strip() if isinstance(x, str) else None
)

# %%
housing_df['subdistrict'] = location_df['subdistrict']

# %%
housing_df = housing_df[['nav-link href','listing-location','subdistrict','price_num','floor_area','price_per_m2','bed','bath']]

# %% [markdown]
# # ✅ **VALIDATION**

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23943 entries, 0 to 29419
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nav-link href     23943 non-null  object
#  1   listing-location  23943 non-null  object
#  2   subdistrict       23943 non-null  object
#  3   price_num         23943 non-null  float64
#  4   floor_area        23943 non-null  float64
#  5   price_per_m2      23943 non-null  float64
#  6   bed               23943 non-null  float64
#  7   bath              23943 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 1.6+ MB

# %%
housing_df.isnull().sum()
# Out:
# nav-link href       0
# listing-location    0
# subdistrict         0
# price_num           0
# floor_area          0
# price_per_m2        0
# bed                 0
# bath                0
# dtype: int64

# %%
housing_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
housing_df.describe()
# Out:
#           price_num     floor_area  price_per_m2           bed          bath
# count  2.394300e+04   23943.000000  2.394300e+04  23943.000000  23943.000000
# mean   3.631614e+09     212.433321  3.337975e+07      3.746857      2.978866
# std    7.285999e+09    2734.818979  5.308890e+08      1.374474      1.374513
# min    4.800000e+07       1.000000  1.000000e+06      0.000000      0.000000
# 25%    1.400000e+09      80.000000  1.333333e+07      3.000000      2.000000
# 50%    2.500000e+09     142.000000  1.851852e+07      4.000000      3.000000
# 75%    4.400000e+09     240.000000  2.433333e+07      4.000000      4.000000
# max    8.500000e+11  400000.000000  2.937500e+10     10.000000     10.000000

# %%
housing_df
# Out:
#                                            nav-link href  \
# 0      https://www.rumah.com/listing-properti/dijual-...
# 1      https://www.rumah.com/listing-properti/dijual-...
# 2      https://www.rumah.com/listing-properti/dijual-...
# 3      https://www.rumah.com/listing-properti/dijual-...
# 4      https://www.rumah.com/listing-properti/dijual-...
# ...                                                  ...
# 29415  https://www.rumah.com/listing-properti/dijual-...
# 29416  https://www.rumah.com/listing-properti/dijual-...
# 29417  https://www.rumah.com/listing-properti/dijual-...
# 29418  https://www.rumah.com/listing-properti/dijual-...
# 29419  https://www.rumah.com/listing-properti/dijual-...
#
#                                 listing-location     subdistrict  \
# 0      Gading Serpong, Tangerang Selatan, Banten  gading serpong
# 1      Gading Serpong, Tangerang Selatan, Banten  gading serpong
# 2      Gading Serpong, Tangerang Selatan, Banten  gading serpong
# 3      Gading Serpong, Tangerang Selatan, Banten  gading serpong
# 4      Gading Serpong, Tangerang Selatan, Banten  gading serpong
# ...                                          ...             ...
# 29415         Bintaro, Tangerang Selatan, Banten         bintaro
# 29416         Bintaro, Tangerang Selatan, Banten         bintaro
# 29417         Bintaro, Tangerang Selatan, Banten         bintaro
# 29418         Bintaro, Tangerang Selatan, Banten         bintaro
# 29419         Bintaro, Tangerang Selatan, Banten         bintaro
#
#           price_num  floor_area  price_per_m2  bed  bath
# 0      6.900000e+09       420.0    20720721.0  5.0   5.0
# 1      4.500000e+09       190.0    12747875.0  3.0   3.0
# 2      3.950000e+09       132.0    30859375.0  3.0   3.0
# 3      3.300000e+09       220.0    18333333.0  4.0   3.0
# 4      3.500000e+09       180.0    27777778.0  3.0   2.0
# ...             ...         ...           ...  ...   ...
# 29415  3.300000e+09       300.0    21710526.0  3.0   3.0
# 29416  4.000000e+09       330.0    36363636.0  8.0   4.0
# 29417  2.200000e+09       160.0    18333333.0  3.0   2.0
# 29418  1.950000e+09       120.0    21666667.0  3.0   2.0
# 29419  5.500000e+09       200.0    30555556.0  4.0   3.0
#
# [23943 rows x 8 columns]
